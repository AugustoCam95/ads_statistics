# %%
import pandas as pd
import numpy as np
import scipy.stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
auto_leve = pd.read_csv("auto-similaridade_leve.csv")
auto_mod = pd.read_csv("auto-similaridade_moderada.csv")
auto_pes = pd.read_csv("auto-similaridade_pesada.csv")
good_leve = pd.read_csv("goodput_leve.csv")
good_mod = pd.read_csv("goodput_moderado.csv")
good_pes =  pd.read_csv("goodput_pesado.csv")
taxa_leve = pd.read_csv("taxa_de_descarte_leve.csv")
taxa_mod = pd.read_csv("taxa_de_descarte_moderada.csv")
taxa_pes =  pd.read_csv("taxa_de_descarte_pesada.csv")

# %%
sns.set_theme(style="darkgrid")
sns.catplot(kind="bar", data=auto_leve, capsize=.2, ci=95)
plt.axis([-0.5,3.5, 0.64,0.71])
plt.xlabel('Configuração Min-Max RED')
plt.ylabel('Hurst')
# Out:
# Text(8.96, 0.5, 'Hurst')

# %%
sns.catplot(kind="bar", data=good_leve, capsize=.2, ci=95)
plt.axis([-0.5,3.5, 0.887,0.892])
plt.xlabel('Configuração Min-Max RED')
plt.ylabel('Goodput(Mbs)')
# Out:
# Text(8.96, 0.5, 'Goodput(Mbs)')

# %%
sns.catplot(kind="bar", data=taxa_leve, capsize=.2, ci=95)
plt.axis([-0.5,3.5, 1.1,1.7])
plt.xlabel('Configuração Min-Max RED')
plt.ylabel('Taxa de Descarte(%)')
# Out:
# Text(8.96, 0.5, 'Taxa de Descarte(%)')

# %%
sns.set_theme(style="darkgrid")
sns.catplot(kind="bar", data=auto_mod, capsize=.2, ci=95)
plt.axis([-0.5,4.5, 0.648,0.654])
plt.xlabel('Configuração Min-Max RED')
plt.ylabel('Hurst')
# Out:
# Text(8.96, 0.5, 'Hurst')

# %%
sns.set_theme(style="darkgrid")
sns.catplot(kind="bar", data=good_mod, capsize=.2, ci=95)
plt.axis([-0.5,4.5, 0.75,0.85])
plt.xlabel('Configuração Min-Max RED')
plt.ylabel('Goodput(Mbs)')
# Out:
# Text(8.96, 0.5, 'Goodput(Mbs)')

# %%
sns.set_theme(style="darkgrid")
sns.catplot(kind="bar", data=taxa_mod, capsize=.2, ci=95)
plt.axis([-0.5,4.5, 10.5,14.5])
plt.xlabel('Configuração Min-Max RED')
plt.ylabel('Taxa de Descarte(%)')
# Out:
# Text(12.085, 0.5, 'Taxa de Descarte(%)')

# %%
sns.set_theme(style="darkgrid")
sns.catplot(kind="bar", data=auto_pes, capsize=.2, ci=95)
plt.axis([-0.5,3.5, 0.6440,0.6485])
plt.xlabel('Configuração Min-Max RED')
plt.ylabel('Hurst')
# Out:
# Text(8.96, 0.5, 'Hurst')

# %%
sns.catplot(kind="bar", data=good_pes, capsize=.2, ci=95)
plt.axis([-0.5,3.5, 0.710,0.760])
plt.xlabel('Configuração Min-Max RED')
plt.ylabel('Goodput(Mbs)')
# Out:
# Text(8.96, 0.5, 'Goodput(Mbs)')

# %%
sns.catplot(kind="bar", data=taxa_pes, capsize=.2, ci=95)
plt.axis([-0.5,3.5, 16,24])
plt.xlabel('Configuração Min-Max RED')
plt.ylabel('Taxa de Descarte(%)')
# Out:
# Text(12.21, 0.5, 'Taxa de Descarte(%)')
