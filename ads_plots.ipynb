# %%
import pandas as pd
import numpy as np
import scipy.stats
import seaborn as sns

# %%
auto_leve = pd.read_csv("auto-similaridade_leve.csv")
auto_mod = pd.read_csv("auto-similaridade_moderada.csv")
auto_pes = pd.read_csv("auto-similaridade_pesada.csv")
good_leve = pd.read_csv("goodput_leve.csv")
good_mod = pd.read_csv("goodput_moderado.csv")
good_pes =  pd.read_csv("goodput_pesado.csv")
taxa_leve = pd.read_csv("taxa_de_descarte_leve.csv")
taxa_mod = pd.read_csv("taxa_de_descarte_moderada.csv")
taxa_pes =  pd.read_csv("taxa_de_descarte_pesada.csv")

# %%
auto_leve
# Out:
#        11-88     21-63     45-90  Droptail
# 0   0.657680  0.706450  0.657262  0.703885
# 1   0.651450  0.692102  0.651410  0.705875
# 2   0.652458  0.694727  0.651458  0.707531
# 3   0.654808  0.706671  0.655082  0.705621
# 4   0.651537  0.681461  0.653444  0.702870
# 5   0.652345  0.696391  0.652924  0.704177
# 6   0.653449  0.688683  0.657577  0.702536
# 7   0.656431  0.708883  0.653433  0.706610
# 8   0.654527  0.672418  0.664010  0.705087
# 9   0.653820  0.709497  0.654403  0.705776
# 10  0.657107  0.673424  0.655555  0.705420
# 11  0.656155  0.690977  0.652960  0.707583
# 12  0.655796  0.696314  0.655792  0.705647
# 13  0.652703  0.672270  0.655683  0.704681
# 14  0.654799  0.675970  0.652248  0.702158
# 15  0.653734  0.689810  0.653463  0.707625
# 16  0.653619  0.695018  0.652712  0.706355
# 17  0.651410  0.685326  0.655432  0.708152
# 18  0.653470  0.701360  0.657214  0.708274
# 19  0.656147  0.670055  0.659135  0.704588
# 20  0.654461  0.709030  0.654807  0.704695
# 21  0.655287  0.673634  0.659063  0.703656
# 22  0.650657  0.703229  0.657173  0.703274
# 23  0.654696  0.682004  0.656200  0.706275
# 24  0.650978  0.688717  0.663232  0.703064
# 25  0.657554  0.701335  0.651341  0.706889
# 26  0.657275  0.675842  0.654501  0.707664
# 27  0.652456  0.658626  0.658218  0.704678
# 28  0.656687  0.700207  0.653541  0.704315
# 29  0.658002  0.701488  0.653308  0.707536
# 30  0.653436  0.673526  0.651664  0.705083
# 31  0.655604  0.671255  0.653645  0.707506
# 32  0.655575  0.672589  0.652591  0.702671
# 33  0.658639  0.657523  0.655777  0.704974
# 34  0.654385  0.707088  0.658301  0.705562
# 35  0.652415  0.687505  0.652375  0.703286
# 36  0.653394  0.672474  0.651768  0.704520
# 37  0.655633  0.673479  0.655084  0.704851
# 38  0.655522  0.691493  0.656983  0.703610
# 39  0.654540  0.672898  0.652493  0.707040
# 40  0.652312  0.688639  0.651751  0.703628
# 41  0.651711  0.673385  0.655268  0.704713
# 42  0.650940  0.657156  0.655783  0.708124
# 43  0.658809  0.674030  0.653493  0.707412
# 44  0.658041  0.691442  0.653957  0.706197
# 45  0.656663  0.700220  0.653534  0.707635
# 46  0.656516  0.656827  0.650928  0.707895
# 47  0.659587  0.700268  0.657561  0.704237
# 48  0.657518  0.709631  0.656494  0.708130
# 49  0.658864  0.685353  0.660117  0.703472

# %%
sns.distplot(auto_leve)

# %%
sns.distplot(auto_mod)

# %%
sns.distplot(auto_pes)
